# %%
import pandas as pd

dataframe_sharks = pd.read_excel('https://www.sharkattackfile.net/spreadsheets/GSAF5.xls')

# %%
dataframe_sharks
# Out:
#              Date    Year        Type       Country                  State  \
# 0     09-Jan-2024  2024.0  Unprovoked     AUSTRALIA        South Australia
# 1     05-Jan-2024  2024.0    Provoked  SOUTH AFRICA  Eastern Cape Province
# 2     30 Dec-2023  2023.0  Unprovoked           USA                 Hawaii
# 3     29 Dec-2023  2023.0  Unprovoked        MEXICO                 Sonora
# 4     28 Dec-2023  2023.0  Unprovoked     AUSTRALIA        South Australia
# ...           ...     ...         ...           ...                    ...
# 6952          NaN     NaN         NaN           NaN                    NaN
# 6953          NaN     NaN         NaN           NaN                    NaN
# 6954          NaN     NaN         NaN           NaN                    NaN
# 6955          NaN     NaN         NaN           NaN                    NaN
# 6956          NaN     NaN         NaN           NaN                    NaN
#
# ...

# %%
dataframe_sharks.shape
# Out:
# (6957, 23)

# %%
dataframe_sharks.describe()
# Out:
#               Year  original order
# count  6930.000000     6799.000000
# mean   1934.249351     3401.152081
# std     273.132061     1963.076319
# min       0.000000        2.000000
# 25%    1947.000000     1701.500000
# 50%    1985.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2024.000000     6802.000000

# %%
dataframe_sharks.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Unnamed: 11        object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
dataframe_sharks.colums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e99a812d57b5> in <module>
# ----> 1 dataframe_sharks.colums
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
for column in dataframe_sharks.colums:
    dataframe_sharks["ST"].value_counts()
    
    titanic_df.columns
