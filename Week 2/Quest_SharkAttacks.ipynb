# %%
import pandas as pd

dataframe_sharks = pd.read_excel('https://www.sharkattackfile.net/spreadsheets/GSAF5.xls')
dataframe_sharks.shape
# Out:
# (6957, 23)

# %%
dataframe_sharks.head()
# Out:
#           Date    Year        Type       Country                  State  \
# 0  09-Jan-2024  2024.0  Unprovoked     AUSTRALIA        South Australia
# 1  05-Jan-2024  2024.0    Provoked  SOUTH AFRICA  Eastern Cape Province
# 2  30 Dec-2023  2023.0  Unprovoked           USA                 Hawaii
# 3  29 Dec-2023  2023.0  Unprovoked        MEXICO                 Sonora
# 4  28 Dec-2023  2023.0  Unprovoked     AUSTRALIA        South Australia
#
#                              Location     Activity                  Name Sex  \
# 0             Walkers Beach, Elliston      Surfing          Murray Adams   M
# 1                       Papiesfontein      Fishing                  male   M
# 2                    Baby Beach, Maui      Surfing          Jason Carter   M
# 3  Tojahui Beach, Yavaros, Huatabampo  Free diving  Víctor Alejandro “N”   M
# 4                         Ethel Beach      Surfing           Khai Cowley   M
#
# ...

# %%
dataframe_sharks.shape
# Out:
# (6957, 23)

# %%
import numpy as np

unique_values= dataframe_sharks.nunique()
unique_values
# Out:
# Date              5992
# Year               259
# Type                11
# Country            224
# State              896
# Location          4503
# Activity          1586
# Name              5677
# Sex                  8
# Age                243
# Injury            4076
# Unnamed: 11         12
# Time               410
# Species           1674
# Source            5291
# pdf               6789
# href formula      6785
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
dataframe_sharks.describe()
# Out:
#               Year  original order
# count  6930.000000     6799.000000
# mean   1934.249351     3401.152081
# std     273.132061     1963.076319
# min       0.000000        2.000000
# 25%    1947.000000     1701.500000
# 50%    1985.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2024.000000     6802.000000

# %%
dataframe_sharks.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Unnamed: 11        object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
dataframe_sharks["Type"].unique()
# Out:
# array(['Unprovoked', 'Provoked', 'Questionable', 'Watercraft',
#        'Sea Disaster', nan, '?', 'Unconfirmed', 'Unverified', 'Invalid',
#        'Under investigation', 'Boat'], dtype=object)

# %%
dataframe_sharks["Sex"].unique() #How to replace lli, mx2, n, .?
# Out:
# array(['M', 'F', nan, ' M', 'M ', 'lli', 'M x 2', 'N', '.'], dtype=object)

# %%
dataframe_sharks["Unnamed: 11"].unique() #This is yes or no for dead so name of colum: survived?
# Out:
# array(['N', 'Y', 'M', nan, 'F', 'n', 'Nq', 'UNKNOWN', 2017, 'Y x 2', ' N',
#        'N ', 'y'], dtype=object)

# %%
"""How to identify the different names of the countries in a faster way?"""

sorted_countries_df= dataframe_sharks.sort_values("Country")

#list(dataframe_sharks["Country"].unique())
#dataframe_sharks["Country"].unique()
sorted_countries_df["Country"].unique()
# Out:
# array([' PHILIPPINES', ' TONGA', 'ADMIRALTY ISLANDS', 'AFRICA', 'ALGERIA',
#        'AMERICAN SAMOA', 'ANDAMAN / NICOBAR ISLANDAS', 'ANDAMAN ISLANDS',
#        'ANGOLA', 'ANTIGUA', 'ARGENTINA', 'ARUBA', 'ASIA?',
#        'ATLANTIC OCEAN', 'AUSTRALIA', 'AZORES', 'BAHAMAS', 'BAHREIN',
#        'BANGLADESH', 'BARBADOS', 'BAY OF BENGAL', 'BELIZE', 'BERMUDA',
#        'BRAZIL', 'BRITISH ISLES', 'BRITISH NEW GUINEA',
#        'BRITISH VIRGIN ISLANDS', 'BRITISH WEST INDIES', 'BURMA',
#        'Between PORTUGAL & INDIA', 'British Overseas Territory', 'CANADA',
#        'CAPE VERDE', 'CARIBBEAN SEA', 'CAYMAN ISLANDS', 'CENTRAL PACIFIC',
#        'CEYLON', 'CEYLON (SRI LANKA)', 'CHILE', 'CHINA', 'COLOMBIA',
#        'COLUMBIA', 'COMOROS', 'COOK ISLANDS', 'COSTA RICA', 'CRETE',
#        'CROATIA', 'CUBA', 'CURACAO', 'CYPRUS', 'Coast of AFRICA',
#        'Coral Sea', 'DIEGO GARCIA', 'DJIBOUTI', 'DOMINICAN REPUBLIC',
#        'ECUADOR', 'EGYPT', 'EGYPT ', 'EGYPT / ISRAEL', 'EL SALVADOR',
# ...

# %%
dataframe_sharks.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
"""#After source I don't know what those columns mean, 
case numbers could be something, pdf href and original 
order to discuss"""

dataframe_sharks.isna().sum()
# Out:
# Date                25
# Year                27
# Type                43
# Country             75
# State              506
# Location           589
# Activity           610
# Name               244
# Sex                604
# Age               3015
# Injury              60
# Unnamed: 11        586
# Time              3547
# Species           3153
# Source              44
# pdf                158
# href formula       138
# href               161
# Case Number        159
# Case Number.1      160
# original order     158
# Unnamed: 21       6956
# Unnamed: 22       6955
# dtype: int64

# %% [markdown]
# 2. Day 2: """Clean & format everything but dates."""

# %%
clean_columns = dataframe_sharks.rename(columns=lambda x: x.lower().replace(" ", "_"))
clean_columns_dataframe_sharks= clean_columns.rename(columns={"unnamed:_11": "survived"}) #This is for some reason not working
clean_columns_dataframe_sharks.head() #Injury, Unnamed: 11 and Time are not shown
clean_columns_dataframe_sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6957 entries, 0 to 6956
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6932 non-null   object
#  1   year            6930 non-null   float64
#  2   type            6914 non-null   object
#  3   country         6882 non-null   object
#  4   state           6451 non-null   object
#  5   location        6368 non-null   object
#  6   activity        6347 non-null   object
#  7   name            6713 non-null   object
#  8   sex             6353 non-null   object
#  9   age             3942 non-null   object
#  10  injury          6897 non-null   object
#  11  survived        6371 non-null   object
#  12  time            3410 non-null   object
#  13  species_        3804 non-null   object
#  14  source          6913 non-null   object
#  15  pdf             6799 non-null   object
#  16  href_formula    6819 non-null   object
# ...

# %%
clean_columns_dataframe_sharks["survived"] = clean_columns_dataframe_sharks["survived"].replace([" N", "Nq", "n", 'N '], "N").replace(["Y x 2", "y"], "Y").replace(["UNKNOWN"], "Y")
clean_columns_dataframe_sharks
# Out:
#              date    year        type       country                  state  \
# 0     09-Jan-2024  2024.0  Unprovoked     AUSTRALIA        South Australia
# 1     05-Jan-2024  2024.0    Provoked  SOUTH AFRICA  Eastern Cape Province
# 2     30 Dec-2023  2023.0  Unprovoked           USA                 Hawaii
# 3     29 Dec-2023  2023.0  Unprovoked        MEXICO                 Sonora
# 4     28 Dec-2023  2023.0  Unprovoked     AUSTRALIA        South Australia
# ...           ...     ...         ...           ...                    ...
# 6952          NaN     NaN         NaN           NaN                    NaN
# 6953          NaN     NaN         NaN           NaN                    NaN
# 6954          NaN     NaN         NaN           NaN                    NaN
# 6955          NaN     NaN         NaN           NaN                    NaN
# 6956          NaN     NaN         NaN           NaN                    NaN
#
# ...

# %%
array(['N', 'Y', 'M', nan, 'F', 'n', 'Nq', 'UNKNOWN', 2017, 'Y x 2', ' N',
       'N ', 'y']
# Out:
#   File "<ipython-input-47-a42fe43d81cf>", line 2
#     'N ', 'y'],
#                ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# 2. Day 2: Apply at least five data cleaning techniques,
# such as handling null values, dropping columns, removing duplicated data, manipulating strings, formatting the data, etc., to prepare the dataset for analysis.

# %%
dataframe_sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6957 entries, 0 to 6956
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6932 non-null   object
#  1   Year            6930 non-null   float64
#  2   Type            6914 non-null   object
#  3   Country         6882 non-null   object
#  4   State           6451 non-null   object
#  5   Location        6368 non-null   object
#  6   Activity        6347 non-null   object
#  7   Name            6713 non-null   object
#  8   Sex             6353 non-null   object
#  9   Age             3942 non-null   object
#  10  Injury          6897 non-null   object
#  11  Unnamed: 11     6371 non-null   object
#  12  Time            3410 non-null   object
#  13  Species         3804 non-null   object
#  14  Source          6913 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6819 non-null   object
# ...
